# %%
##Data Visualization Handson

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [raw]
# ##Use the cars dataset for the following questions that contains the following-
# The dataset contains information about 260 cars that include horsepower, cubic inches, time to
#
# 60, brand, make year, weight, cylinders, mpg, etc.

# %%
data1 = pd.read_csv('cars.csv', skipinitialspace = True)
data1
# Out:
#       mpg  cylinders  cubicinches   hp  weightlbs  time-to-60  year    brand
# 0    14.0          8        350.0  165     4209.0          12  1972      US.
# 1    31.9          4         89.0   71     1925.0          14  1980  Europe.
# 2    17.0          8        302.0  140     3449.0          11  1971      US.
# 3    15.0          8        400.0  150     3761.0          10  1971      US.
# 4    30.5          4         98.0   63     2051.0          17  1978      US.
# ..    ...        ...          ...  ...        ...         ...   ...      ...
# 256  17.0          8        305.0  130     3840.0          15  1980      US.
# 257  36.1          4         91.0   60     1800.0          16  1979   Japan.
# 258  22.0          6        232.0  112     2835.0          15  1983      US.
# 259  18.0          6        232.0  100     3288.0          16  1972      US.
# 260  22.0          6        250.0  105     3353.0          15  1977      US.
#
# [261 rows x 8 columns]

# %%
##1. Create scatter plots for the following data, make sure all the plots appear in the same
 #plane with x-labels and y-labels evenly spaced.
#a. Create scatter plots with between (mpg-hp, mpg-weight), and (hp-mpg,
#hp-time-to-60) with respect to each brand.

# %%
##Plotting 4 scatter plots in one 

fig=plt.subplots(2,2,figsize=(15,15))
plt.subplot(2,2,1)
sns.scatterplot(x=data1['mpg'], y=data1['hp'], data=data1, hue=data1['brand'])
plt.title('mpg vs hp')
plt.xlabel('mpg')
plt.ylabel('hp')

plt.subplot(2,2,2)
sns.scatterplot(x=data1['mpg'],y=data1['weightlbs'],data=data1, hue=data1['brand'])
plt.title('mpg vs weightlbs')
plt.xlabel('mpg')
plt.ylabel('weightlbs')

plt.subplot(2,2,3)
sns.scatterplot(x=data1['hp'],y=data1['mpg'],data=data1, hue=data1['brand'])
plt.title('hp vs mpg')
plt.xlabel('hp')
plt.ylabel('mpg')

plt.subplot(2,2,4)
sns.scatterplot(x=data1['hp'],y=data1['time-to-60'],data=data1, hue=data1['brand'])
plt.title('hp vs time-to-60')
plt.xlabel('hp')
plt.ylabel('time-to-60')

plt.show()

# %%
##2. Create bar plots for the following, make sure all the plots appear in the same plane with
   #x-labels and y-labels evenly spaced.

##a. Create a bar plot that shows the visual representation of hp, mpg, weight,
#time-to-60 with respect to the number of cylinders for each of the brands.

# %%
fig=plt.subplots(2,2,figsize=(15,15))
plt.subplot(2,2,1)
sns.barplot(x=data1['cylinders'], y=data1['hp'], data=data1, hue=data1['brand'])
plt.title('cylinders vs hp')
plt.xlabel('cylinders')
plt.ylabel('hp')

plt.subplot(2,2,2)
sns.barplot(x=data1['cylinders'],y=data1['mpg'],data=data1, hue=data1['brand'])
plt.title('cylinders vs mpg')
plt.xlabel('cylinders')
plt.ylabel('mpg')

plt.subplot(2,2,3)
sns.barplot(x=data1['cylinders'],y=data1['weightlbs'],data=data1, hue=data1['brand'])
plt.title('cylinders vs weightlbs')
plt.xlabel('cylinders')
plt.ylabel('weightlbs')

plt.subplot(2,2,4)
sns.barplot(x=data1['cylinders'],y=data1['time-to-60'],data=data1, hue=data1['brand'])
plt.title('cylinders vs time-to-60')
plt.xlabel('cylinders')
plt.ylabel('time-to-60')

plt.show()

# %%
##b. Create a bar plot that shows the visual representation of hp, mpg, weight and
#time-to-60 with respect to the years, for each brand.

# %%
fig=plt.subplots(2,2,figsize=(15,15))
plt.subplot(2,2,1)
sns.barplot(x=data1['cylinders'], y=data1['hp'], data=data1, hue=data1['brand'])
plt.title('year vs hp')
plt.xlabel('year')
plt.ylabel('hp')

plt.subplot(2,2,2)
sns.barplot(x=data1['cylinders'],y=data1['mpg'],data=data1, hue=data1['brand'])
plt.title('year vs mpg')
plt.xlabel('year')
plt.ylabel('mpg')

plt.subplot(2,2,3)
sns.barplot(x=data1['cylinders'],y=data1['weightlbs'],data=data1, hue=data1['brand'])
plt.title('year vs weightlbs')
plt.xlabel('year')
plt.ylabel('weightlbs')

plt.subplot(2,2,4)
sns.barplot(x=data1['cylinders'],y=data1['time-to-60'],data=data1, hue=data1['brand'])
plt.title('year vs time-to-60')
plt.xlabel('year')
plt.ylabel('time-to-60')

plt.show()

# %%
##3. Create box plots for the following:
#a. Create box plots for the columns in the step1 with respect to the number of
#cylinders and brand respectively.

# %%
fig=plt.subplots(2,2,figsize=(15,15))
plt.subplot(2,2,1)
sns.boxplot(x=data1['cylinders'], y=data1['hp'], data=data1, hue=data1['brand'])
plt.title('cylinders vs hp')
plt.xlabel('cylinders')
plt.ylabel('hp')

plt.subplot(2,2,2)
sns.boxplot(x=data1['cylinders'],y=data1['mpg'],data=data1, hue=data1['brand'])
plt.title('cylinders vs mpg')
plt.xlabel('cylinders')
plt.ylabel('mpg')

plt.subplot(2,2,3)
sns.boxplot(x=data1['cylinders'],y=data1['weightlbs'],data=data1, hue=data1['brand'])
plt.title('cylinders vs weightlbs')
plt.xlabel('cylinders')
plt.ylabel('weightlbs')

plt.subplot(2,2,4)
sns.boxplot(x=data1['cylinders'],y=data1['time-to-60'],data=data1, hue=data1['brand'])
plt.title('cylinders vs time-to-60')
plt.xlabel('cylinders')
plt.ylabel('time-to-60')

plt.show()

# %%
##4. Create pair plots for the entire data to study various patterns in the data.
#a. Create pair plots with respect to brand, number of cylinders, year, etc.

# %%
sns.pairplot(data1)

# %%
sns.pairplot(data1, hue='brand')

# %%
sns.pairplot(data1, hue='cylinders')

# %%
sns.pairplot(data1, hue='year')

# %%
##5. Create a heatmap for the entire data to study correlation between each of the columns.

# %%
sns.heatmap(data1.corr(),annot=True,cmap='Greens')
plt.show()

# %%
##6. Create a histogram for the following:
#a. Create histograms for hp, mpg, time-to-60, weight lbs, cubic inches, year, with
respect to brand.

# %%
fig=plt.subplots(3,2,figsize=(15,15))                    ##plot can be 1,6  2,3  6,1
plt.subplot(3,2,1)
sns.histplot(x=data1['hp'], hue=data1['brand'])

plt.subplot(3,2,2)
sns.histplot(x=data1['mpg'], hue=data1['brand'])

plt.subplot(3,2,3)
sns.histplot(x=data1['time-to-60'], hue=data1['brand'])

plt.subplot(3,2,4)
sns.histplot(x=data1['weightlbs'], hue=data1['brand'])

plt.subplot(3,2,5)
sns.histplot(x=data1['cubicinches'], hue=data1['brand'])

plt.subplot(3,2,6)
sns.histplot(x=data1['year'], hue=data1['brand'])


plt.show()

# %%
##7. Create line plots for the following:
#a. Line plot between hp-mpg, hp-(time-to-60), mpg-(time-to-60), hp-weight lbs,
  #mpg-weight lbs, cubic inches-weight lbs.

# %%
fig=plt.subplots(3,2,figsize=(15,15))                    ##plot can be 1,6  2,3  6,1
plt.subplot(3,2,1)
sns.lineplot(x=data1['hp'], y=data1['mpg'], hue=data1['brand'])

plt.subplot(3,2,2)
sns.lineplot(x=data1['hp'], y=data1['time-to-60'], hue=data1['brand'])

plt.subplot(3,2,3)
sns.lineplot(x=data1['mpg'], y=data1['time-to-60'], hue=data1['brand'])

plt.subplot(3,2,4)
sns.lineplot(x=data1['hp'], y=data1['weightlbs'], hue=data1['brand'])

plt.subplot(3,2,5)
sns.lineplot(x=data1['mpg'], y=data1['weightlbs'], hue=data1['brand'])

plt.subplot(3,2,6)
sns.lineplot(x=data1['cubicinches'], y=data1['weightlbs'], hue=data1['brand'])

plt.show()

# %%
#8. Create a pie chart for the following columns and their distribution in the data:
#a. Brands

# %%
data1['brand'].value_counts()
# Out:
# US.        162
# Japan.      51
# Europe.     48
# Name: brand, dtype: int64

# %%
pie1 = data1['brand'].value_counts()
pie1.plot.pie(autopct='%0.2f%%')
plt.show()

# %%
##9. Create violin plots for the following:
#a. hp, mpg, time-to-60, with respect to the number of cylinders for each brand.

# %%
fig=plt.subplots(3,2,figsize=(15,15))                   
plt.subplot(3,1,1)
sns.violinplot(x=data1['cylinders'], y=data1['hp'], hue=data1['brand'])

plt.subplot(3,1,2)
sns.violinplot(x=data1['cylinders'], y=data1['mpg'], hue=data1['brand'])

plt.subplot(3,1,3)
sns.violinplot(x=data1['cylinders'], y=data1['time-to-60'], hue=data1['brand'])

plt.show()

# %%
##10. Create categorical plots for the following:
#a. Hp, mpg, time-to-60, weight, cubic inches, with respect to each brand for various
#numbers of cylinders.

# %%
sns.catplot(x='cylinders', y='hp', hue='brand', data=data1)

sns.catplot(x='cylinders', y='mpg', hue='brand', data=data1)

sns.catplot(x='cylinders', y='time-to-60', hue='brand', data=data1)

sns.catplot(x='cylinders', y='weightlbs', hue='brand', data=data1)

sns.catplot(x='cylinders', y='cubicinches', hue='brand', data=data1)
plt.show()

# %%
##11. Create the area charts for the following:
#a. Mpg with respect to each brand of the car

# %%
sns.histplot(data1, x='mpg',hue='brand', element='poly')            ##element can be step or poly
plt.show()

# %%
##12. Create Doughnut plots to represent the following:
#a. The cars are based on various counts of cylinders.

# %%
data1.cylinders.value_counts().plot.pie()                     ##create pie chart and add black circle at center
centre=plt.Circle((0,0), 0.70, fc='black')                      ##radius =0.70
fig=plt.gcf()                                                   ##to get current fig
fig.gca().add_artist(centre)
plt.show()
